# %%
import pandas as pd

pd.read_csv('C:\\workspace_mestrado\\dados_cvm_trimestrais\\base_dados_tri_2024.csv', sep=';')
# Out:
#         Unnamed: 0    DT_REFER  VERSAO                             DENOM_CIA  \
# 0                1  2011-03-31       1  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 1                3  2011-03-31       1  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 2                5  2011-03-31       1  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 3                7  2011-03-31       1  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 4                9  2011-03-31       1  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# ...            ...         ...     ...                                   ...
# 849576       30303  2024-03-31       1                            DEXCO S.A.
# 849577       30305  2024-03-31       1                            DEXCO S.A.
# 849578       30307  2024-03-31       1                            DEXCO S.A.
# 849579       30309  2024-03-31       1                            DEXCO S.A.
# 849580       30311  2024-03-31       1                            DEXCO S.A.
#
# ...
